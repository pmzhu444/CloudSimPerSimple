# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./file/3_23/nearest.csv", sep=",")
df = df.drop(['Unnamed: 15'], axis=1)  
df
# Out:
#         time dcName  requestNum  finishedRequestNum  dcUsage  dcConsume  \
# 0          0  DC_CR       48636               48636    0.379  31422.177
# 1          0  DC_OS        6592                6592    0.039  24563.373
# 2          0  DC_MB      296113              136800    1.000  61800.000
# 3          0  DC_SH       75554               75554    0.515  41586.375
# 4          0  DC_LA       89640               89640    0.572  39217.500
# ...      ...    ...         ...                 ...      ...        ...
# 5040  604800  DC_CR       49412               49412    0.385  31584.750
# 5041  604800  DC_OS        5931                5931    0.035  24404.603
# 5042  604800  DC_MB      282562              136800    1.000  61800.000
# 5043  604800  DC_SH       86503               86503    0.589  43639.313
# 5044  604800  DC_LA       89329               89329    0.570  39159.188
#
#       dcPrice   reSupply  reUsage  reDcUsage  reBaUsage    rePrice   baSupply  \
# 0       0.000  49518.217    1.000      0.635      0.366   8199.189  18096.041
# 1       0.000  41038.522    1.000      0.599      0.402   1641.541  16475.150
# 2       6.140  17597.658    1.000      1.000      0.000   7421.861      0.000
# 3       1.779  28782.728    1.000      1.000      0.000  27762.627      0.000
# 4       4.160   9271.137    1.000      1.000      0.000   8344.024      0.000
# ...       ...        ...      ...        ...        ...        ...        ...
# 5040    0.000  50588.620    1.000      0.625      0.376   3666.386  19003.870
# 5041    0.000  40307.661    0.606      0.606      0.000   1612.307      0.000
# 5042    0.000  28210.008    1.000      1.000      0.000   3931.138 -33589.992
# 5043    2.800  23485.737    1.000      1.000      0.000  18361.900      0.000
# 5044    2.053  24383.485    1.000      1.000      0.000  21945.137      0.000
#
#       baPrice       cost
# 0       0.000   8199.189
# 1       0.000   1641.541
# 2       0.000   7428.001
# 3       0.000  27764.406
# 4       0.000   8348.183
# ...       ...        ...
# 5040    0.000   3666.386
# 5041    0.000   1612.307
# 5042    0.934   3932.071
# 5043    0.000  18364.700
# 5044    0.000  21947.189
#
# [5045 rows x 15 columns]

# %%
df_CR = df.loc[df['dcName'] == 'DC_CR'].reset_index()
df_OS = df.loc[df['dcName'] == 'DC_OS'].reset_index()
df_SH = df.loc[df['dcName'] == 'DC_SH'].reset_index()
df_MB = df.loc[df['dcName'] == 'DC_MB'].reset_index()
df_LA = df.loc[df['dcName'] == 'DC_LA'].reset_index()

# %%
df_DcConsume = pd.DataFrame({'CR':df_CR['dcConsume'], 'MB':df_MB['dcConsume'], 'OS':df_OS['dcConsume'], 'SH':df_SH['dcConsume'], 'LA':df_LA['dcConsume']})

# %%
df_DcConsume.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'OS':df_OS['reSupply'], 'MB':df_MB['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RequestNum = pd.DataFrame({'CR':df_CR['requestNum'], 'OS':df_OS['requestNum'], 'MB':df_MB['requestNum'], 'SH':df_SH['requestNum'], 'LA':df_LA['requestNum']})

# %%
df_RequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_FinishedRequestNum = pd.DataFrame({'CR':df_CR['finishedRequestNum'], 'OS':df_OS['finishedRequestNum'], 'MB':df_MB['finishedRequestNum'], 'SH':df_SH['finishedRequestNum'], 'LA':df_LA['finishedRequestNum']})

# %%
df_FinishedRequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_BaSupply = pd.DataFrame({'CR':df_CR['baSupply'], 'OS':df_OS['baSupply'], 'MB':df_MB['baSupply'], 'SH':df_SH['baSupply'], 'LA':df_LA['baSupply']})

# %%
df_BaSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcPrice = pd.DataFrame({'CR':df_CR['dcPrice'], 'OS':df_OS['dcPrice'], 'MB':df_MB['dcPrice'], 'SH':df_SH['dcPrice'], 'LA':df_LA['dcPrice']})

# %%
df_DcPrice = df_DcPrice * 2

# %%
df_DcPrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_RePrice = pd.DataFrame({'CR':df_CR['rePrice'], 'OS':df_OS['rePrice'], 'MB':df_MB['rePrice'], 'SH':df_SH['rePrice'], 'LA':df_LA['rePrice']})

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_Cost = pd.DataFrame({'CR':df_CR['cost'], 'OS':df_OS['cost'], 'MB':df_MB['cost'], 'SH':df_SH['cost'], 'LA':df_LA['cost']})

# %%
df_Cost.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReUsage = pd.DataFrame({'CR':df_CR['reUsage'], 'OS':df_OS['reUsage'], 'MB':df_MB['reUsage'], 'SH':df_SH['reUsage'], 'LA':df_LA['reUsage']})

# %%
df_ReUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReDcUsage = pd.DataFrame({'CR':df_CR['reDcUsage'], 'OS':df_OS['reDcUsage'], 'MB':df_MB['reDcUsage'], 'SH':df_SH['reDcUsage'], 'LA':df_LA['reDcUsage']})
df_ReDcUsage.boxplot()
# Out:
# <AxesSubplot:>

# %%
df_ReDcUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df = df_ReDcUsage[df_ReDcUsage['LA']>0.8]

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
names = ['CR', 'OS', 'MB', 'SH', 'LA']
for name in names:
    for i in range(len(df_RePrice[name])):
        df_RePrice[name][i] = df_RePrice[name][i] * df_ReDcUsage[name][i]

# %%
df_RePrice = df_RePrice / 100

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("energyCost/$")
plt.legend(loc = 1)
plt.show()
