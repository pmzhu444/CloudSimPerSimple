# %%
import numpy as np
import pandas as pd

import matplotlib
matplotlib.rcParams['backend'] = 'SVG'
import matplotlib.pyplot as plt

plt.rc('font',family='Times New Roman')

# %% [markdown]
# rr_data

# %%
df_rr = pd.read_csv("./file/4_11/500000/rr.csv", sep=",")
df_rr = df_rr.drop(['Unnamed: 15'], axis=1)

df_CR_rr = df_rr.loc[df_rr['dcName'] == 'DC_CR'].reset_index()
df_OS_rr = df_rr.loc[df_rr['dcName'] == 'DC_OS'].reset_index()
df_SH_rr = df_rr.loc[df_rr['dcName'] == 'DC_SH'].reset_index()
df_MB_rr = df_rr.loc[df_rr['dcName'] == 'DC_MB'].reset_index()
df_LA_rr = df_rr.loc[df_rr['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_rr = pd.DataFrame({'CR':df_CR_rr['baSupply'], 'MB':df_MB_rr['baSupply'], 'OS':df_OS_rr['baSupply'], 'SH':df_SH_rr['baSupply'], 'LA':df_LA_rr['baSupply']})

# %% [markdown]
# ne_data

# %%
df_ne = pd.read_csv("./file/4_11/500000/ne.csv", sep=",")
df_ne = df_ne.drop(['Unnamed: 15'], axis=1)

df_CR_ne = df_ne.loc[df_ne['dcName'] == 'DC_CR'].reset_index()
df_OS_ne = df_ne.loc[df_ne['dcName'] == 'DC_OS'].reset_index()
df_SH_ne = df_ne.loc[df_ne['dcName'] == 'DC_SH'].reset_index()
df_MB_ne = df_ne.loc[df_ne['dcName'] == 'DC_MB'].reset_index()
df_LA_ne = df_ne.loc[df_ne['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_ne = pd.DataFrame({'CR':df_CR_ne['baSupply'], 'MB':df_MB_ne['baSupply'], 'OS':df_OS_ne['baSupply'], 'SH':df_SH_ne['baSupply'], 'LA':df_LA_ne['baSupply']})

# %% [markdown]
# ca_data

# %%
df_ca = pd.read_csv("./file/4_11/500000/ca.csv", sep=",")
df_ca = df_ca.drop(['Unnamed: 15'], axis=1)

df_CR_ca = df_ca.loc[df_ca['dcName'] == 'DC_CR'].reset_index()
df_OS_ca = df_ca.loc[df_ca['dcName'] == 'DC_OS'].reset_index()
df_SH_ca = df_ca.loc[df_ca['dcName'] == 'DC_SH'].reset_index()
df_MB_ca = df_ca.loc[df_ca['dcName'] == 'DC_MB'].reset_index()
df_LA_ca = df_ca.loc[df_ca['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_ca = pd.DataFrame({'CR':df_CR_ca['baSupply'], 'MB':df_MB_ca['baSupply'], 'OS':df_OS_ca['baSupply'], 'SH':df_SH_ca['baSupply'], 'LA':df_LA_ca['baSupply']})

# %% [markdown]
# mp_data

# %%
df_mp = pd.read_csv("./file/4_11/500000/mp.csv", sep=",")
df_mp = df_mp.drop(['Unnamed: 15'], axis=1)

df_CR_mp = df_mp.loc[df_mp['dcName'] == 'DC_CR'].reset_index()
df_OS_mp = df_mp.loc[df_mp['dcName'] == 'DC_OS'].reset_index()
df_SH_mp = df_mp.loc[df_mp['dcName'] == 'DC_SH'].reset_index()
df_MB_mp = df_mp.loc[df_mp['dcName'] == 'DC_MB'].reset_index()
df_LA_mp = df_mp.loc[df_mp['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_mp = pd.DataFrame({'CR':df_CR_mp['baSupply'], 'MB':df_MB_mp['baSupply'], 'OS':df_OS_mp['baSupply'], 'SH':df_SH_mp['baSupply'], 'LA':df_LA_mp['baSupply']})

# %% [markdown]
# mg_data

# %%
df_mg = pd.read_csv("./file/4_11/500000/mg.csv", sep=",")
df_mg = df_mg.drop(['Unnamed: 15'], axis=1)

df_CR_mg = df_mg.loc[df_mg['dcName'] == 'DC_CR'].reset_index()
df_OS_mg = df_mg.loc[df_mg['dcName'] == 'DC_OS'].reset_index()
df_SH_mg = df_mg.loc[df_mg['dcName'] == 'DC_SH'].reset_index()
df_MB_mg = df_mg.loc[df_mg['dcName'] == 'DC_MB'].reset_index()
df_LA_mg = df_mg.loc[df_mg['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_mg = pd.DataFrame({'CR':df_CR_mg['baSupply'], 'MB':df_MB_mg['baSupply'], 'OS':df_OS_mg['baSupply'], 'SH':df_SH_mg['baSupply'], 'LA':df_LA_mg['baSupply']})

# %% [markdown]
# mc_data

# %%
df_mc = pd.read_csv("./file/4_11/500000/mc.csv", sep=",")
df_mc = df_mc.drop(['Unnamed: 15'], axis=1)

df_CR_mc = df_mc.loc[df_mc['dcName'] == 'DC_CR'].reset_index()
df_OS_mc = df_mc.loc[df_mc['dcName'] == 'DC_OS'].reset_index()
df_SH_mc = df_mc.loc[df_mc['dcName'] == 'DC_SH'].reset_index()
df_MB_mc = df_mc.loc[df_mc['dcName'] == 'DC_MB'].reset_index()
df_LA_mc = df_mc.loc[df_mc['dcName'] == 'DC_LA'].reset_index()

df_BaSupply_mc = pd.DataFrame({'CR':df_CR_mc['baSupply'], 'MB':df_MB_mc['baSupply'], 'OS':df_OS_mc['baSupply'], 'SH':df_SH_mc['baSupply'], 'LA':df_LA_mc['baSupply']})

# %% [markdown]
# Battery

# %%
fig = plt.figure(figsize=(10,18),dpi=200)

ax1 = fig.add_subplot(611)
ax1.plot(df_BaSupply_rr['CR'], label='CR', linewidth = '0.8')
ax1.plot(df_BaSupply_rr['MB'], label='MB', linewidth = '0.8')
ax1.plot(df_BaSupply_rr['OS'], label='OS', linewidth = '0.8')
ax1.plot(df_BaSupply_rr['SH'], label='SH', linewidth = '0.8')
ax1.plot(df_BaSupply_rr['LA'], label='LA', linewidth = '0.8')
ax1.set_xlim(0, 1008)
#ax1.set_ylim(40000, 65000)
ax1.set_title("(a) RR", y = -0.2)
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=5)

ax2 = fig.add_subplot(612, sharex = ax1)
ax2.plot(df_BaSupply_ne['CR'], linewidth = '0.8')
ax2.plot(df_BaSupply_ne['MB'], linewidth = '0.8')
ax2.plot(df_BaSupply_ne['OS'], linewidth = '0.8')
ax2.plot(df_BaSupply_ne['SH'], linewidth = '0.8')
ax2.plot(df_BaSupply_ne['LA'], linewidth = '0.8')
ax2.set_xlim(0, 1008)
#ax2.set_ylim(20000, 65000)
ax2.set_title("(b) NE", y = -0.2)

ax3 = fig.add_subplot(613, sharex = ax1)
ax3.plot(df_BaSupply_ca['CR'], linewidth = '0.8')
ax3.plot(df_BaSupply_ca['MB'], linewidth = '0.8')
ax3.plot(df_BaSupply_ca['OS'], linewidth = '0.8')
ax3.plot(df_BaSupply_ca['SH'], linewidth = '0.8')
ax3.plot(df_BaSupply_ca['LA'], linewidth = '0.8')
ax3.set_xlim(0, 1008)
#ax3.set_ylim(30000, 65000)
ax3.set_title("(c) CA", y = -0.2)

ax4 = fig.add_subplot(614, sharex = ax1)
ax4.plot(df_BaSupply_mp['CR'], linewidth = '0.8')
ax4.plot(df_BaSupply_mp['MB'], linewidth = '0.8')
ax4.plot(df_BaSupply_mp['OS'], linewidth = '0.8')
ax4.plot(df_BaSupply_mp['SH'], linewidth = '0.8')
ax4.plot(df_BaSupply_mp['LA'], linewidth = '0.8')
ax4.set_xlim(0, 1008)
#ax4.set_ylim(20000, 65000)
ax4.set_title("(d) MP", y = -0.2)

ax5 = fig.add_subplot(615, sharex = ax1)
ax5.plot(df_BaSupply_mg['CR'], linewidth = '0.8')
ax5.plot(df_BaSupply_mg['MB'], linewidth = '0.8')
ax5.plot(df_BaSupply_mg['OS'], linewidth = '0.8')
ax5.plot(df_BaSupply_mg['SH'], linewidth = '0.8')
ax5.plot(df_BaSupply_mg['LA'], linewidth = '0.8')
ax5.set_xlim(0, 1008)
#ax5.set_ylim(25000, 65000)
ax5.set_title("(e) MG", y = -0.2)

ax6 = fig.add_subplot(616, sharex = ax1)
ax6.plot(df_BaSupply_mc['CR'], linewidth = '0.8')
ax6.plot(df_BaSupply_mc['MB'], linewidth = '0.8')
ax6.plot(df_BaSupply_mc['OS'], linewidth = '0.8')
ax6.plot(df_BaSupply_mc['SH'], linewidth = '0.8')
ax6.plot(df_BaSupply_mc['LA'], linewidth = '0.8')
ax6.set_xlim(0, 1008)
#ax6.set_ylim(25000, 65000)
ax6.set_title("(f) MC", y = -0.2)

plt.xticks(np.arange(0, 1152, 144), np.arange(0, 192, 24))
plt.savefig("../pic/4_13/svg/battery.svg", format='svg')
#plt.show()
