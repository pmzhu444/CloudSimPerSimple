# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./file/3_27/500000/mg.csv", sep=",")
df = df.drop(['Unnamed: 15'], axis=1)  
df
# Out:
#         time dcName  requestNum  finishedRequestNum  dcUsage  dcConsume  \
# 0          0  DC_CR      104310              104310    0.811  41574.556
# 1          0  DC_OS      104307              104307    0.608  44376.677
# 2          0  DC_MB      104303              104303    0.763  55706.813
# 3          0  DC_SH      104301              104301    0.711  46976.438
# 4          0  DC_LA      104299              104299    0.665  41930.199
# ...      ...    ...         ...                 ...      ...        ...
# 5040  604800  DC_CR      112782              125891    0.979  45720.975
# 5041  604800  DC_OS      128795              128795    0.750  47942.315
# 5042  604800  DC_MB      145953              136800    1.000  61800.000
# 5043  604800  DC_SH       57311               57311    0.391  38165.813
# 5044  604800  DC_LA       77789               77789    0.496  36995.438
#
#       dcPrice   reSupply  reUsage  reDcUsage  reBaUsage    rePrice   baSupply  \
# 0       0.000  50927.834      1.0      0.817      0.184   8300.238   9353.279
# 1       0.482  40912.598      1.0      1.000      0.000   1636.504      0.000
# 2       5.367  17066.512      1.0      1.000      0.000   7366.734      0.000
# 3       2.535  28729.140      1.0      1.000      0.000  27754.309      0.000
# 4       4.475   9711.157      1.0      1.000      0.000   8740.042      0.000
# ...       ...        ...      ...        ...        ...        ...        ...
# 5040    0.000  49161.324      1.0      0.931      0.070   3936.200   3440.350
# 5041    0.763  42451.088      1.0      1.000      0.000   1698.044      0.000
# 5042    0.000  29057.447      1.0      1.000      0.000   3791.672 -32742.553
# 5043    2.094  23095.227      1.0      1.000      0.000  17973.648      0.000
# 5044    1.665  25013.167      1.0      1.000      0.000  22511.851      0.000
#
#       baPrice       cost
# 0        0.00   8300.238
# 1        0.00   1636.986
# 2        0.00   7372.101
# 3        0.00  27756.844
# 4        0.00   8744.517
# ...       ...        ...
# 5040     0.00   3936.200
# 5041     0.00   1698.807
# 5042     0.91   3792.581
# 5043     0.00  17975.742
# 5044     0.00  22513.515
#
# [5045 rows x 15 columns]

# %%
df_CR = df.loc[df['dcName'] == 'DC_CR'].reset_index()
df_OS = df.loc[df['dcName'] == 'DC_OS'].reset_index()
df_SH = df.loc[df['dcName'] == 'DC_SH'].reset_index()
df_MB = df.loc[df['dcName'] == 'DC_MB'].reset_index()
df_LA = df.loc[df['dcName'] == 'DC_LA'].reset_index()

# %%
df_DcConsume = pd.DataFrame({'CR':df_CR['dcConsume'], 'MB':df_MB['dcConsume'], 'OS':df_OS['dcConsume'], 'SH':df_SH['dcConsume'], 'LA':df_LA['dcConsume']})

# %%
df_DcConsume.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcConsume['CR'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['OS'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['MB'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['SH'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['LA'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'OS':df_OS['reSupply'], 'MB':df_MB['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RequestNum = pd.DataFrame({'CR':df_CR['requestNum'], 'OS':df_OS['requestNum'], 'MB':df_MB['requestNum'], 'SH':df_SH['requestNum'], 'LA':df_LA['requestNum']})

# %%
df_RequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_FinishedRequestNum = pd.DataFrame({'CR':df_CR['finishedRequestNum'], 'OS':df_OS['finishedRequestNum'], 'MB':df_MB['finishedRequestNum'], 'SH':df_SH['finishedRequestNum'], 'LA':df_LA['finishedRequestNum']})

# %%
df_FinishedRequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_BaSupply = pd.DataFrame({'CR':df_CR['baSupply'], 'MB':df_MB['baSupply'], 'OS':df_OS['baSupply'], 'SH':df_SH['baSupply'], 'LA':df_LA['baSupply']})

# %%
df_BaSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcPrice = pd.DataFrame({'CR':df_CR['dcPrice'], 'MB':df_MB['dcPrice'], 'OS':df_OS['dcPrice'], 'SH':df_SH['dcPrice'], 'LA':df_LA['dcPrice']})

# %%
df_DcPrice = df_DcPrice * 2

# %%
df_DcPrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_RePrice = pd.DataFrame({'CR':df_CR['rePrice'], 'OS':df_OS['rePrice'], 'MB':df_MB['rePrice'], 'SH':df_SH['rePrice'], 'LA':df_LA['rePrice']})

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_Cost = pd.DataFrame({'CR':df_CR['cost'], 'OS':df_OS['cost'], 'MB':df_MB['cost'], 'SH':df_SH['cost'], 'LA':df_LA['cost']})

# %%
df_Cost.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReUsage = pd.DataFrame({'CR':df_CR['reUsage'], 'OS':df_OS['reUsage'], 'MB':df_MB['reUsage'], 'SH':df_SH['reUsage'], 'LA':df_LA['reUsage']})

# %%
df_ReUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReDcUsage = pd.DataFrame({'CR':df_CR['reDcUsage'], 'OS':df_OS['reDcUsage'], 'MB':df_MB['reDcUsage'], 'SH':df_SH['reDcUsage'], 'LA':df_LA['reDcUsage']})
df_ReDcUsage.boxplot()
# Out:
# <AxesSubplot:>

# %%
df_ReDcUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RePrice
# Out:
#             CR        OS        MB         SH         LA
# 0     8156.786  1673.566  7456.344  28274.918   8550.196
# 1     8221.452  1561.409  7923.725  27439.357   8888.711
# 2     8777.511  1596.795  7748.778  25902.408   8635.296
# 3     8502.072  1613.086  7329.118  25847.479   8313.400
# 4     8347.850  1676.521  7669.756  25898.375   8183.496
# ...        ...       ...       ...        ...        ...
# 1004  4015.273  1607.978  3781.037  19119.705  21504.547
# 1005  3901.908  1644.340  4030.351  18910.947  21678.396
# 1006  3757.382  1620.252  3895.614  17665.859  21087.808
# 1007  3837.140  1635.327  3901.615  18041.648  22188.527
# 1008  3678.621  1604.230  3988.590  18004.148  21021.628
#
# [1009 rows x 5 columns]

# %%
names = ['CR', 'OS', 'MB', 'SH', 'LA']
for name in names:
    for i in range(len(df_RePrice[name])):
        df_RePrice[name][i] = df_RePrice[name][i] * df_ReDcUsage[name][i]

# %%
df_RePrice = df_RePrice / 100

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("energyCost/$")
plt.legend(loc = 1)
plt.show()

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'MB':df_MB['reSupply'], 'OS':df_OS['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})
names = ['CR', 'OS', 'MB', 'SH', 'LA']
for name in names:
    for i in range(len(df_ReSupply[name])):
        df_ReSupply[name][i] = df_ReSupply[name][i] * df_ReDcUsage[name][i]

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()
