# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./file/3_23/maxpower.csv", sep=",")
df = df.drop(['Unnamed: 15'], axis=1)  
df
# Out:
#         time dcName  requestNum  finishedRequestNum  dcUsage  dcConsume  \
# 0          0  DC_CR      103366              103366    0.804  41531.149
# 1          0  DC_OS      103363              103363    0.602  44320.901
# 2          0  DC_MB      103362              103362    0.756  55530.375
# 3          0  DC_SH      103358              103358    0.704  46799.625
# 4          0  DC_LA      103356              103356    0.659  41885.428
# ...      ...    ...         ...                 ...      ...        ...
# 5040  604800  DC_CR      136604              128640    1.000  45900.000
# 5041  604800  DC_OS      331735              171840    1.000  54000.000
# 5042  604800  DC_MB           0              136800    1.000  61800.000
# 5043  604800  DC_SH       53438               84408    0.575  43246.500
# 5044  604800  DC_LA           0                   0    0.000  21240.000
#
#       dcPrice   reSupply  reUsage  reDcUsage  reBaUsage    rePrice   baSupply  \
# 0       0.000  49204.608    1.000      0.845      0.156   8572.139   7673.460
# 1       0.381  41581.236    1.000      1.000      0.000   1663.250      0.000
# 2       5.299  17378.943    1.000      1.000      0.000   7337.659      0.000
# 3       2.666  27607.909    1.000      1.000      0.000  26624.152      0.000
# 4       4.433   9974.482    1.000      1.000      0.000   8977.034      0.000
# ...       ...        ...      ...        ...        ...        ...        ...
# 5040    0.000  52368.094    1.000      0.877      0.124   3842.101   6468.094
# 5041    1.566  42726.268    1.000      1.000      0.000   1709.051      0.000
# 5042    0.000  29711.740    1.000      1.000      0.000   4008.398 -32088.260
# 5043    2.785  23195.064    1.000      1.000      0.000  18164.802      0.000
# 5044    0.000  24444.345    0.869      0.869      0.000  21999.911      0.000
#
#       baPrice       cost
# 0       0.000   8572.139
# 1       0.000   1663.630
# 2       0.000   7342.958
# 3       0.000  26626.818
# 4       0.000   8981.466
# ...       ...        ...
# 5040    0.000   3842.101
# 5041    0.000   1710.617
# 5042    0.892   4009.289
# 5043    0.000  18167.587
# 5044    0.000  21999.911
#
# [5045 rows x 15 columns]

# %%
df_CR = df.loc[df['dcName'] == 'DC_CR'].reset_index()
df_OS = df.loc[df['dcName'] == 'DC_OS'].reset_index()
df_SH = df.loc[df['dcName'] == 'DC_SH'].reset_index()
df_MB = df.loc[df['dcName'] == 'DC_MB'].reset_index()
df_LA = df.loc[df['dcName'] == 'DC_LA'].reset_index()

# %%
df_DcConsume = pd.DataFrame({'CR':df_CR['dcConsume'], 'OS':df_OS['dcConsume'], 'MB':df_MB['dcConsume'], 'SH':df_SH['dcConsume'], 'LA':df_LA['dcConsume']})

# %%
df_DcConsume.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcConsume['CR'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['LA'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['OS'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['SH'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_DcConsume['MB'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'OS':df_OS['reSupply'], 'MB':df_MB['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RequestNum = pd.DataFrame({'CR':df_CR['requestNum'], 'OS':df_OS['requestNum'], 'MB':df_MB['requestNum'], 'SH':df_SH['requestNum'], 'LA':df_LA['requestNum']})

# %%
df_RequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RequestNum['LA']
# Out:
# 0       103356
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 1004         0
# 1005         0
# 1006         0
# 1007         0
# 1008         0
# Name: LA, Length: 1009, dtype: int64

# %%
df_FinishedRequestNum = pd.DataFrame({'CR':df_CR['finishedRequestNum'], 'OS':df_OS['finishedRequestNum'], 'MB':df_MB['finishedRequestNum'], 'SH':df_SH['finishedRequestNum'], 'LA':df_LA['finishedRequestNum']})

# %%
df_FinishedRequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_BaSupply = pd.DataFrame({'CR':df_CR['baSupply'], 'OS':df_OS['baSupply'], 'MB':df_MB['baSupply'], 'SH':df_SH['baSupply'], 'LA':df_LA['baSupply']})

# %%
df_BaSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcPrice = pd.DataFrame({'CR':df_CR['dcPrice'], 'OS':df_OS['dcPrice'], 'MB':df_MB['dcPrice'], 'SH':df_SH['dcPrice'], 'LA':df_LA['dcPrice']})

# %%
df_DcPrice = df_DcPrice * 2

# %%
df_DcPrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_RePrice = pd.DataFrame({'CR':df_CR['rePrice'], 'OS':df_OS['rePrice'], 'MB':df_MB['rePrice'], 'SH':df_SH['rePrice'], 'LA':df_LA['rePrice']})

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_Cost = pd.DataFrame({'CR':df_CR['cost'], 'OS':df_OS['cost'], 'MB':df_MB['cost'], 'SH':df_SH['cost'], 'LA':df_LA['cost']})

# %%
df_Cost.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReUsage = pd.DataFrame({'CR':df_CR['reUsage'], 'OS':df_OS['reUsage'], 'MB':df_MB['reUsage'], 'SH':df_SH['reUsage'], 'LA':df_LA['reUsage']})

# %%
df_ReUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReDcUsage = pd.DataFrame({'CR':df_CR['reDcUsage'], 'OS':df_OS['reDcUsage'], 'MB':df_MB['reDcUsage'], 'SH':df_SH['reDcUsage'], 'LA':df_LA['reDcUsage']})
df_ReDcUsage.boxplot()
# Out:
# <AxesSubplot:>

# %%
df_ReDcUsage['OS'].plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()
