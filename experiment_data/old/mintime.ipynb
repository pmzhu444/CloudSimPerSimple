# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./file/3_27/500000/ca.csv", sep=",")
df = df.drop(['Unnamed: 15'], axis=1)  
df
# Out:
#         time dcName  requestNum  finishedRequestNum  dcUsage  dcConsume  \
# 0          0  DC_CR       90545               90545    0.704  39327.052
# 1          0  DC_OS      120954              120954    0.704  46757.714
# 2          0  DC_MB       96290               96290    0.704  54204.375
# 3          0  DC_SH      103384              103384    0.704  46804.500
# 4          0  DC_LA      110479              110479    0.704  43262.611
# ...      ...    ...         ...                 ...      ...        ...
# 5040  604800  DC_CR       89923               89923    0.700  39275.789
# 5041  604800  DC_OS      120120              120120    0.700  46727.320
# 5042  604800  DC_MB       95625               95625    0.700  54079.688
# 5043  604800  DC_SH      102669              102669    0.699  46670.438
# 5044  604800  DC_LA      109718              109718    0.700  43182.773
#
#       dcPrice   reSupply  reUsage  reDcUsage  reBaUsage    rePrice   baSupply  \
# 0       0.000  49280.252      1.0      0.799      0.202   8808.561   9953.200
# 1       0.760  41285.993      1.0      1.000      0.000   1651.440      0.000
# 2       4.968  18436.032      1.0      1.000      0.000   8004.668      0.000
# 3       2.549  28454.584      1.0      1.000      0.000  27458.985      0.000
# 4       4.644   9833.008      1.0      1.000      0.000   8849.708      0.000
# ...       ...        ...      ...        ...        ...        ...        ...
# 5040    0.000  51610.716      1.0      0.762      0.239   3684.492  12334.928
# 5041    0.702  41677.947      1.0      1.000      0.000   1667.118      0.000
# 5042    0.000  29457.346      1.0      1.000      0.000   3871.760 -24622.341
# 5043    3.298  22930.060      1.0      1.000      0.000  17946.447      0.000
# 5044    2.497  25207.355      1.0      1.000      0.000  22686.620      0.000
#
#       baPrice       cost
# 0       0.000   8808.561
# 1       0.000   1652.200
# 2       0.000   8009.636
# 3       0.000  27461.534
# 4       0.000   8854.351
# ...       ...        ...
# 5040    0.000   3684.492
# 5041    0.000   1667.820
# 5042    0.684   3872.444
# 5043    0.000  17949.745
# 5044    0.000  22689.117
#
# [5045 rows x 15 columns]

# %%
df_CR = df.loc[df['dcName'] == 'DC_CR'].reset_index()
df_OS = df.loc[df['dcName'] == 'DC_OS'].reset_index()
df_SH = df.loc[df['dcName'] == 'DC_SH'].reset_index()
df_MB = df.loc[df['dcName'] == 'DC_MB'].reset_index()
df_LA = df.loc[df['dcName'] == 'DC_LA'].reset_index()

# %%
df_DcConsume = pd.DataFrame({'CR':df_CR['dcConsume'], 'MB':df_MB['dcConsume'], 'OS':df_OS['dcConsume'], 'SH':df_SH['dcConsume'], 'LA':df_LA['dcConsume']})

# %%
df_DcConsume.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcConsume
# Out:
#              CR         OS         MB         SH         LA
# 0     39330.114  46759.619  54213.000  46814.063  43266.986
# 1     39380.958  47181.322  54386.625  47000.250  43334.919
# 2     39251.575  46714.215  54034.688  46622.250  43139.158
# 3     39349.285  46999.929  54272.063  46877.813  43293.656
# 4     39289.059  46734.929  54108.000  46701.375  43205.064
# ...         ...        ...        ...        ...        ...
# 1004  42236.898  50171.756  57513.375  50265.591  46869.757
# 1005  41566.735  49595.228  56911.125  49830.182  46174.931
# 1006  42189.049  49775.895  57371.625  50226.742  46780.706
# 1007  42220.316  50099.671  57459.375  50251.774  46841.440
# 1008  39213.901  46695.114  53975.813  46559.250  43055.198
#
# [1009 rows x 5 columns]

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'OS':df_OS['reSupply'], 'MB':df_MB['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_RequestNum = pd.DataFrame({'CR':df_CR['requestNum'], 'OS':df_OS['requestNum'], 'MB':df_MB['requestNum'], 'SH':df_SH['requestNum'], 'LA':df_LA['requestNum']})

# %%
#df_RequestNum[0:144].plot(figsize= (20, 5))
df_RequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.ylim()
plt.show()

# %%
df_FinishedRequestNum = pd.DataFrame({'CR':df_CR['finishedRequestNum'], 'OS':df_OS['finishedRequestNum'], 'MB':df_MB['finishedRequestNum'], 'SH':df_SH['finishedRequestNum'], 'LA':df_LA['finishedRequestNum']})

# %%
df_FinishedRequestNum.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_FinishedRequestNum
# Out:
#           CR      OS      MB      SH      LA
# 0      90589  121013   96336  103435  110533
# 1      91461  122175   97262  104428  111598
# 2      89693  119816   95385  102412  109440
# 3      90885  121408   96651  103775  110897
# 4      90065  120311   95776  102834  109893
# ...      ...     ...     ...     ...     ...
# 1004  107141  143120  113938  122333  130728
# 1005  104120  139086  110726  118883  127044
# 1006  106431  142173  113182  121524  129863
# 1007  106870  142761  113650  122022  130398
# 1008   89399  119424   95071  102076  109081
#
# [1009 rows x 5 columns]

# %%
df_BaSupply = pd.DataFrame({'CR':df_CR['baSupply'], 'MB':df_MB['baSupply'], 'OS':df_OS['baSupply'], 'SH':df_SH['baSupply'], 'LA':df_LA['baSupply']})

# %%
df_BaSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_DcPrice = pd.DataFrame({'CR':df_CR['dcPrice'], 'MB':df_MB['dcPrice'], 'OS':df_OS['dcPrice'], 'SH':df_SH['dcPrice'], 'LA':df_LA['dcPrice']})

# %%
df_DcPrice = df_DcPrice * 2

# %%
df_DcPrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()

# %%
df_RePrice = pd.DataFrame({'CR':df_CR['rePrice'], 'OS':df_OS['rePrice'], 'MB':df_MB['rePrice'], 'SH':df_SH['rePrice'], 'LA':df_LA['rePrice']})

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_Cost = pd.DataFrame({'CR':df_CR['cost'], 'OS':df_OS['cost'], 'MB':df_MB['cost'], 'SH':df_SH['cost'], 'LA':df_LA['cost']})

# %%
df_Cost.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReUsage = pd.DataFrame({'CR':df_CR['reUsage'], 'OS':df_OS['reUsage'], 'MB':df_MB['reUsage'], 'SH':df_SH['reUsage'], 'LA':df_LA['reUsage']})

# %%
df_ReUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
df_ReDcUsage = pd.DataFrame({'CR':df_CR['reDcUsage'], 'OS':df_OS['reDcUsage'], 'MB':df_MB['reDcUsage'], 'SH':df_SH['reDcUsage'], 'LA':df_LA['reDcUsage']})
df_ReDcUsage.boxplot()
# Out:
# <AxesSubplot:>

# %%
df_ReDcUsage.plot(figsize= (20, 5))
plt.xlim(-40, 1050)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.show()

# %%
names = ['CR', 'OS', 'MB', 'SH', 'LA']
for name in names:
    for i in range(len(df_RePrice[name])):
        df_RePrice[name][i] = df_RePrice[name][i] * df_ReDcUsage[name][i]

# %%
df_RePrice = df_RePrice / 100

# %%
df_RePrice.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("energyCost/$")
plt.legend(loc = 1)
plt.show()

# %%
df_ReSupply = pd.DataFrame({'CR':df_CR['reSupply'], 'MB':df_MB['reSupply'], 'OS':df_OS['reSupply'], 'SH':df_SH['reSupply'], 'LA':df_LA['reSupply']})
names = ['CR', 'OS', 'MB', 'SH', 'LA']
for name in names:
    for i in range(len(df_ReSupply[name])):
        df_ReSupply[name][i] = df_ReSupply[name][i] * df_ReDcUsage[name][i]

# %%
df_ReSupply.plot(figsize= (20, 5))
plt.xlim(-40, 1080)
plt.xticks(np.arange(0, 1008, 72), np.arange(0, 168, 12))
plt.xlabel("time/h")
plt.ylabel("power/kw")
plt.legend(loc = 1)
plt.show()
