# %%
import numpy as np
import pandas as pd

import matplotlib
matplotlib.rcParams['backend'] = 'SVG'
import matplotlib.pyplot as plt

# %% [markdown]
# no_battery

# %%
df_rr = pd.read_csv("./file/4_11/rr.csv", sep=",")
df_rr = df_rr.drop(['Unnamed: 15'], axis=1)

df_CR_rr = df_rr.loc[df_rr['dcName'] == 'DC_CR'].reset_index()
df_CR_rr = df_CR_rr[df_CR_rr['reSupply'] > 19740]
print(df_CR_rr.mean()['reUsage'])
df_OS_rr = df_rr.loc[df_rr['dcName'] == 'DC_OS'].reset_index()
df_OS_rr = df_OS_rr[df_OS_rr['reSupply'] > 22980]
print(df_OS_rr.mean()['reUsage'])
df_SH_rr = df_rr.loc[df_rr['dcName'] == 'DC_SH'].reset_index()
df_SH_rr = df_SH_rr[df_SH_rr['reSupply'] > 24840]
print(df_SH_rr.mean()['reUsage'])
df_MB_rr = df_rr.loc[df_rr['dcName'] == 'DC_MB'].reset_index()
df_MB_rr = df_MB_rr[df_MB_rr['reSupply'] > 28440]
print(df_MB_rr.mean()['reUsage'])
df_LA_rr = df_rr.loc[df_rr['dcName'] == 'DC_LA'].reset_index()
df_LA_rr = df_LA_rr[df_LA_rr['reSupply'] > 21240]
print(df_LA_rr.mean()['reUsage'])
# Out:
# 0.943041958041958
# 0.9219118644067799
# 0.9155235849056604
# 0.9224109589041096
# 0.9498216783216783

# %%
df_ne = pd.read_csv("./file/4_11/ne.csv", sep=",")
df_ne = df_ne.drop(['Unnamed: 15'], axis=1)

df_CR_ne = df_ne.loc[df_ne['dcName'] == 'DC_CR'].reset_index()
df_CR_ne = df_CR_ne[df_CR_ne['reSupply'] > 19740]
print(df_CR_ne.mean()['reUsage'])
df_OS_ne = df_ne.loc[df_ne['dcName'] == 'DC_OS'].reset_index()
df_OS_ne = df_OS_ne[df_OS_ne['reSupply'] > 22980]
print(df_OS_ne.mean()['reUsage'])
df_SH_ne = df_ne.loc[df_ne['dcName'] == 'DC_SH'].reset_index()
df_SH_ne = df_SH_ne[df_SH_ne['reSupply'] > 24840]
print(df_SH_ne.mean()['reUsage'])
df_MB_ne = df_ne.loc[df_ne['dcName'] == 'DC_MB'].reset_index()
df_MB_ne = df_MB_ne[df_MB_ne['reSupply'] > 28440]
print(df_MB_ne.mean()['reUsage'])
df_LA_ne = df_ne.loc[df_ne['dcName'] == 'DC_LA'].reset_index()
df_LA_ne = df_LA_ne[df_LA_ne['reSupply'] > 21240]
print(df_LA_ne.mean()['reUsage'])
# Out:
# 0.8476478873239437
# 0.6648110918544194
# 0.8553475177304964
# 0.9362679558011051
# 0.9363403508771929

# %%
df_ca = pd.read_csv("./file/4_11/ca.csv", sep=",")
df_ca = df_ca.drop(['Unnamed: 15'], axis=1)

df_CR_ca = df_ca.loc[df_ca['dcName'] == 'DC_CR'].reset_index()
df_CR_ca = df_CR_ca[df_CR_ca['reSupply'] > 19740]
print(df_CR_ca.mean()['reUsage'])
df_OS_ca = df_ca.loc[df_ca['dcName'] == 'DC_OS'].reset_index()
df_OS_ca = df_OS_ca[df_OS_ca['reSupply'] > 22980]
print(df_OS_ca.mean()['reUsage'])
df_SH_ca = df_ca.loc[df_ca['dcName'] == 'DC_SH'].reset_index()
df_SH_ca = df_SH_ca[df_SH_ca['reSupply'] > 24840]
print(df_SH_ca.mean()['reUsage'])
df_MB_ca = df_ca.loc[df_ca['dcName'] == 'DC_MB'].reset_index()
df_MB_ca = df_MB_ca[df_MB_ca['reSupply'] > 28440]
print(df_MB_ca.mean()['reUsage'])
df_LA_ca = df_ca.loc[df_ca['dcName'] == 'DC_LA'].reset_index()
df_LA_ca = df_LA_ca[df_LA_ca['reSupply'] > 21240]
print(df_LA_ca.mean()['reUsage'])
# Out:
# 0.9170573476702508
# 0.9324098639455783
# 0.9147939110070257
# 0.9022555555555556
# 0.9548310344827586

# %%
df_mp = pd.read_csv("./file/4_11/mp.csv", sep=",")
df_mp = df_mp.drop(['Unnamed: 15'], axis=1)

df_CR_mp = df_mp.loc[df_mp['dcName'] == 'DC_CR'].reset_index()
df_CR_mp = df_CR_mp[df_CR_mp['reSupply'] > 19740]
print(df_CR_mp.mean()['reUsage'])
df_OS_mp = df_mp.loc[df_mp['dcName'] == 'DC_OS'].reset_index()
df_OS_mp = df_OS_mp[df_OS_mp['reSupply'] > 22980]
print(df_OS_mp.mean()['reUsage'])
df_SH_mp = df_mp.loc[df_mp['dcName'] == 'DC_SH'].reset_index()
df_SH_mp = df_SH_mp[df_SH_mp['reSupply'] > 24840]
print(df_SH_mp.mean()['reUsage'])
df_MB_mp = df_mp.loc[df_mp['dcName'] == 'DC_MB'].reset_index()
df_MB_mp = df_MB_mp[df_MB_mp['reSupply'] > 28440]
print(df_MB_mp.mean()['reUsage'])
df_LA_mp = df_mp.loc[df_mp['dcName'] == 'DC_LA'].reset_index()
df_LA_mp = df_LA_mp[df_LA_mp['reSupply'] > 21240]
print(df_LA_mp.mean()['reUsage'])
# Out:
# 0.9505053003533571
# 0.9427261904761907
# 0.8235687645687646
# 0.9160165745856352
# 0.6707397260273973

# %%
df_mg = pd.read_csv("./file/4_11/mg.csv", sep=",")
df_mg = df_mg.drop(['Unnamed: 15'], axis=1)

df_CR_mg = df_mg.loc[df_mg['dcName'] == 'DC_CR'].reset_index()
df_CR_mg = df_CR_mg[df_CR_mg['reSupply'] > 19740]
print(df_CR_mg.mean()['reUsage'])
df_OS_mg = df_mg.loc[df_mg['dcName'] == 'DC_OS'].reset_index()
df_OS_mg = df_OS_mg[df_OS_mg['reSupply'] > 22980]
print(df_OS_mg.mean()['reUsage'])
df_SH_mg = df_mg.loc[df_mg['dcName'] == 'DC_SH'].reset_index()
df_SH_mg = df_SH_mg[df_SH_mg['reSupply'] > 24840]
print(df_SH_mg.mean()['reUsage'])
df_MB_mg = df_mg.loc[df_mg['dcName'] == 'DC_MB'].reset_index()
df_MB_mg = df_MB_mg[df_MB_mg['reSupply'] > 28440]
print(df_MB_mg.mean()['reUsage'])
df_LA_mg = df_mg.loc[df_mg['dcName'] == 'DC_LA'].reset_index()
df_LA_mg = df_LA_mg[df_LA_mg['reSupply'] > 21240]
print(df_LA_mg.mean()['reUsage'])
# Out:
# 0.9477722419928826
# 0.9429347079037801
# 0.9343309859154929
# 0.9353147632311978
# 0.9660206896551725

# %%
df_mc = pd.read_csv("./file/4_11/mc.csv", sep=",")
df_mc = df_mc.drop(['Unnamed: 15'], axis=1)

df_CR_mc = df_mc.loc[df_mc['dcName'] == 'DC_CR'].reset_index()
df_CR_mc = df_CR_mc[df_CR_mc['reSupply'] > 19740]
print(df_CR_mc.mean()['reUsage'])
df_OS_mc = df_mc.loc[df_mc['dcName'] == 'DC_OS'].reset_index()
df_OS_mc = df_OS_mc[df_OS_mc['reSupply'] > 22980]
print(df_OS_mc.mean()['reUsage'])
df_SH_mc = df_mc.loc[df_mc['dcName'] == 'DC_SH'].reset_index()
df_SH_mc = df_SH_mc[df_SH_mc['reSupply'] > 24840]
print(df_SH_mc.mean()['reUsage'])
df_MB_mc = df_mc.loc[df_mc['dcName'] == 'DC_MB'].reset_index()
df_MB_mc = df_MB_mc[df_MB_mc['reSupply'] > 28440]
print(df_MB_mc.mean()['reUsage'])
df_LA_mc = df_mc.loc[df_mc['dcName'] == 'DC_LA'].reset_index()
df_LA_mc = df_LA_mc[df_LA_mc['reSupply'] > 21240]
print(df_LA_mc.mean()['reUsage'])
# Out:
# 0.8649290780141845
# 0.8680186440677964
# 0.65325
# 0.8573643835616438
# 0.7336724738675959

# %%
cr = (0.903041958041958,  0.8476478873239437, 0.9170573476702508, 0.9505053003533571, 0.9477722419928826, 0.8649290780141845)
os = (0.8619118644067799, 0.6648110918544194, 0.9324098639455783, 0.9427261904761907, 0.9429347079037801, 0.8680186440677964)
sh = (0.8555235849056604, 0.8553475177304964, 0.9147939110070257, 0.8235687645687646, 0.9343309859154929, 0.65325)
mb = (0.8424109589041096, 0.9362679558011051, 0.9022555555555556, 0.9160165745856352, 0.9353147632311978, 0.8573643835616438)
la = (0.9008216783216783, 0.9363403508771929, 0.9548310344827586, 0.6707397260273973, 0.9660206896551725, 0.7336724738675959)

# %%
n_groups = 6

fig, ax = plt.subplots(figsize=(10, 5), dpi = 200)
 
index = np.arange(n_groups) * 1.5
bar_width = 0.2
 
opacity = 1
error_config = {'ecolor': '0.3'}
 

rects1 = ax.bar(index, cr, bar_width,
#                alpha=opacity, 
                 color='b',
#                error_kw=error_config,
                label='CR')
 
rects2 = ax.bar(index + bar_width, mb, bar_width,
 #               alpha=opacity, 
                 color='orange',
 #               error_kw=error_config,
                label='MB')
 
rects3 = ax.bar(index + bar_width * 2, os, bar_width,
  #              alpha=opacity, 
                 color='green',
  #              error_kw=error_config,
                label='OS')

rects3 = ax.bar(index + bar_width * 3, sh, bar_width,
   #             alpha=opacity, 
                 color='r',
   #             error_kw=error_config,
                label='SH')

rects3 = ax.bar(index + bar_width * 4, la, bar_width,
    #            alpha=opacity, 
                 color='darkviolet',
    #            error_kw=error_config,
                label='LA')
 
ax.set_xticks(index + bar_width*1.5)
ax.set_xticklabels(('RR', 'NE', 'CA', 'MP', 'MG', 'MC'))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=5)
plt.xlabel("Scheduling algorithms")
plt.ylabel("Usage")
 
fig.tight_layout()
#plt.savefig('result.png', dpi=200)
#plt.xlim(-0.5, 10.2)
plt.ylim(0.4, 1)
plt.savefig("../pic/4_13/svg/usage.svg", format='svg')
#plt.show()

# %% [markdown]
# with_battery

# %%
df_rr = pd.read_csv("./file/4_11/500000/rr.csv", sep=",")
df_rr = df_rr.drop(['Unnamed: 15'], axis=1)

df_CR_rr = df_rr.loc[df_rr['dcName'] == 'DC_CR'].reset_index()
df_CR_rr = df_CR_rr[df_CR_rr['reSupply'] > 19740]
print(df_CR_rr.mean()['reUsage'] - cr[0])
df_OS_rr = df_rr.loc[df_rr['dcName'] == 'DC_OS'].reset_index()
df_OS_rr = df_OS_rr[df_OS_rr['reSupply'] > 22980]
print(df_OS_rr.mean()['reUsage'] - os[0])
df_SH_rr = df_rr.loc[df_rr['dcName'] == 'DC_SH'].reset_index()
df_SH_rr = df_SH_rr[df_SH_rr['reSupply'] > 24840]
print(df_SH_rr.mean()['reUsage'] - sh[0])
df_MB_rr = df_rr.loc[df_rr['dcName'] == 'DC_MB'].reset_index()
df_MB_rr = df_MB_rr[df_MB_rr['reSupply'] > 28440]
print(df_MB_rr.mean()['reUsage'] - mb[0])
df_LA_rr = df_rr.loc[df_rr['dcName'] == 'DC_LA'].reset_index()
df_LA_rr = df_LA_rr[df_LA_rr['reSupply'] > 21240]
print(df_LA_rr.mean()['reUsage'] - la[0])
# Out:
# 0.056958041958041994
# 0.030414074159773263
# 0.04746453860977906
# 0.06564398615083544
# 0.04142570843790361

# %%
df_ne = pd.read_csv("./file/4_11/500000/ne.csv", sep=",")
df_ne = df_ne.drop(['Unnamed: 15'], axis=1)

df_CR_ne = df_ne.loc[df_ne['dcName'] == 'DC_CR'].reset_index()
df_CR_ne = df_CR_ne[df_CR_ne['reSupply'] > 19740]
print(df_CR_ne.mean()['reUsage'] - cr[1])
df_OS_ne = df_ne.loc[df_ne['dcName'] == 'DC_OS'].reset_index()
df_OS_ne = df_OS_ne[df_OS_ne['reSupply'] > 22980]
print(df_OS_ne.mean()['reUsage'] - os[1])
df_SH_ne = df_ne.loc[df_ne['dcName'] == 'DC_SH'].reset_index()
df_SH_ne = df_SH_ne[df_SH_ne['reSupply'] > 24840]
print(df_SH_ne.mean()['reUsage'] - sh[1])
df_MB_ne = df_ne.loc[df_ne['dcName'] == 'DC_MB'].reset_index()
df_MB_ne = df_MB_ne[df_MB_ne['reSupply'] > 28440]
print(df_MB_ne.mean()['reUsage'] - mb[1])
df_LA_ne = df_ne.loc[df_ne['dcName'] == 'DC_LA'].reset_index()
df_LA_ne = df_LA_ne[df_LA_ne['reSupply'] > 21240]
print(df_LA_ne.mean()['reUsage'] - la[1])
# Out:
# 0.1349190140845069
# 0.10754204906238862
# 0.06860777638715077
# 0.05586940683625763
# 0.050241530655908084

# %%
df_ca = pd.read_csv("./file/4_11/500000/ca.csv", sep=",")
df_ca = df_ca.drop(['Unnamed: 15'], axis=1)

df_CR_ca = df_ca.loc[df_ca['dcName'] == 'DC_CR'].reset_index()
df_CR_ca = df_CR_ca[df_CR_ca['reSupply'] > 19740]
print(df_CR_ca.mean()['reUsage'] - cr[2])
df_OS_ca = df_ca.loc[df_ca['dcName'] == 'DC_OS'].reset_index()
df_OS_ca = df_OS_ca[df_OS_ca['reSupply'] > 22980]
print(df_OS_ca.mean()['reUsage'] - os[2])
df_SH_ca = df_ca.loc[df_ca['dcName'] == 'DC_SH'].reset_index()
df_SH_ca = df_SH_ca[df_SH_ca['reSupply'] > 24840]
print(df_SH_ca.mean()['reUsage'] - sh[2])
df_MB_ca = df_ca.loc[df_ca['dcName'] == 'DC_MB'].reset_index()
df_MB_ca = df_MB_ca[df_MB_ca['reSupply'] > 28440]
print(df_MB_ca.mean()['reUsage'] - mb[2])
df_LA_ca = df_ca.loc[df_ca['dcName'] == 'DC_LA'].reset_index()
df_LA_ca = df_LA_ca[df_LA_ca['reSupply'] > 21240]
print(df_LA_ca.mean()['reUsage'] - la[2])
# Out:
# 0.08288550947260642
# 0.02598151536476645
# 0.047008469945355236
# 0.08339904054472302
# 0.037945597819646903

# %%
df_mp = pd.read_csv("./file/4_11/500000/mp.csv", sep=",")
df_mp = df_mp.drop(['Unnamed: 15'], axis=1)

df_CR_mp = df_mp.loc[df_mp['dcName'] == 'DC_CR'].reset_index()
df_CR_mp = df_CR_mp[df_CR_mp['reSupply'] > 19740]
print(df_CR_mp.mean()['reUsage'] - cr[3])
df_OS_mp = df_mp.loc[df_mp['dcName'] == 'DC_OS'].reset_index()
df_OS_mp = df_OS_mp[df_OS_mp['reSupply'] > 22980]
print(df_OS_mp.mean()['reUsage'] - os[3])
df_SH_mp = df_mp.loc[df_mp['dcName'] == 'DC_SH'].reset_index()
df_SH_mp = df_SH_mp[df_SH_mp['reSupply'] > 24840]
print(df_SH_mp.mean()['reUsage'] - sh[3])
df_MB_mp = df_mp.loc[df_mp['dcName'] == 'DC_MB'].reset_index()
df_MB_mp = df_MB_mp[df_MB_mp['reSupply'] > 28440]
print(df_MB_mp.mean()['reUsage'] - mb[3])
df_LA_mp = df_mp.loc[df_mp['dcName'] == 'DC_LA'].reset_index()
df_LA_mp = df_LA_mp[df_LA_mp['reSupply'] > 21240]
print(df_LA_mp.mean()['reUsage'] - la[3])
# Out:
# 0.04949469964664288
# 0.021673809523809262
# 0.10046861860880552
# 0.07066835692121409
# 0.22872626036716048

# %%
df_mg = pd.read_csv("./file/4_11/500000/mg.csv", sep=",")
df_mg = df_mg.drop(['Unnamed: 15'], axis=1)

df_CR_mg = df_mg.loc[df_mg['dcName'] == 'DC_CR'].reset_index()
df_CR_mg = df_CR_mg[df_CR_mg['reSupply'] > 19740]
print(df_CR_mg.mean()['reUsage'] - cr[4])
df_OS_mg = df_mg.loc[df_mg['dcName'] == 'DC_OS'].reset_index()
df_OS_mg = df_OS_mg[df_OS_mg['reSupply'] > 22980]
print(df_OS_mg.mean()['reUsage'] - os[4])
df_SH_mg = df_mg.loc[df_mg['dcName'] == 'DC_SH'].reset_index()
df_SH_mg = df_SH_mg[df_SH_mg['reSupply'] > 24840]
print(df_SH_mg.mean()['reUsage'] - sh[4])
df_MB_mg = df_mg.loc[df_mg['dcName'] == 'DC_MB'].reset_index()
df_MB_mg = df_MB_mg[df_MB_mg['reSupply'] > 28440]
print(df_MB_mg.mean()['reUsage'] - mb[4])
df_LA_mg = df_mg.loc[df_mg['dcName'] == 'DC_LA'].reset_index()
df_LA_mg = df_LA_mg[df_LA_mg['reSupply'] > 21240]
print(df_LA_mg.mean()['reUsage'] - la[4])
# Out:
# 0.05222775800711743
# 0.021391154165185333
# 0.03925586854460095
# 0.056811287188970216
# 0.029615049176442643

# %%
df_mc = pd.read_csv("./file/4_11/500000/mc.csv", sep=",")
df_mc = df_mc.drop(['Unnamed: 15'], axis=1)

df_CR_mc = df_mc.loc[df_mc['dcName'] == 'DC_CR'].reset_index()
df_CR_mc = df_CR_mc[df_CR_mc['reSupply'] > 19740]
print(df_CR_mc.mean()['reUsage'] - cr[5])
df_OS_mc = df_mc.loc[df_mc['dcName'] == 'DC_OS'].reset_index()
df_OS_mc = df_OS_mc[df_OS_mc['reSupply'] > 22980]
print(df_OS_mc.mean()['reUsage'] - os[5])
df_SH_mc = df_mc.loc[df_mc['dcName'] == 'DC_SH'].reset_index()
df_SH_mc = df_SH_mc[df_SH_mc['reSupply'] > 24840]
print(df_SH_mc.mean()['reUsage'] - sh[5])
df_MB_mc = df_mc.loc[df_mc['dcName'] == 'DC_MB'].reset_index()
df_MB_mc = df_MB_mc[df_MB_mc['reSupply'] > 28440]
print(df_MB_mc.mean()['reUsage'] - mb[5])
df_LA_mc = df_mc.loc[df_mc['dcName'] == 'DC_LA'].reset_index()
df_LA_mc = df_LA_mc[df_LA_mc['reSupply'] > 21240]
print(df_LA_mc.mean()['reUsage'] - la[5])
# Out:
# 0.09995472480271683
# 0.07241992248510465
# 0.11188776722090277
# 0.09048451753725728
# 0.18469116249604034

# %%
cr_ = (0.056958041958041994, 0.1349190140845069,  0.08288550947260642,  0.04949469964664288,  0.05222775800711743,  0.09995472480271683)
os_ = (0.030414074159773263, 0.10754204906238862, 0.02598151536476645,  0.021673809523809262, 0.041391154165185333, 0.07241992248510465)
sh_ = (0.04746453860977906,  0.06860777638715077, 0.047008469945355236, 0.10046861860880552,  0.04925586854460095,  0.11188776722090277)
mb_ = (0.06564398615083544,  0.05586940683625763, 0.08339904054472302,  0.07066835692121409,  0.056811287188970216, 0.09048451753725728)
la_ = (0.04142570843790361,  0.050241530655908084,0.037945597819646903, 0.22872626036716048,  0.029615049176442643, 0.18469116249604034)

# %%
n_groups = 6

fig, ax = plt.subplots(figsize=(10, 5), dpi = 200)
 
index = np.arange(n_groups) * 1.5
bar_width = 0.2
 
opacity = 1
error_config = {'ecolor': '0.3'}
 

rects1 = ax.bar(index, cr, bar_width,
#                alpha=opacity, 
                 color='b',
#                error_kw=error_config,
                label='CR')
rects1 = ax.bar(index, cr_, bar_width,
#                alpha=opacity, 
                 color='gray',
#                error_kw=error_config,
                bottom=cr,
                )
 
rects2 = ax.bar(index + bar_width, mb, bar_width,
 #               alpha=opacity, 
                 color='orange',
 #               error_kw=error_config,
                label='MB')
rects2 = ax.bar(index + bar_width, mb_, bar_width,
 #               alpha=opacity, 
                 color='gray',
                 bottom=mb,
 #               error_kw=error_config
               )
 
rects3 = ax.bar(index + bar_width * 2, os, bar_width,
  #              alpha=opacity, 
                 color='green',
  #              error_kw=error_config,
                label='OS')
rects3 = ax.bar(index + bar_width * 2, os_, bar_width,
  #              alpha=opacity, 
                 color='gray',
                 bottom=os,
  #              error_kw=error_config,
                )

rects3 = ax.bar(index + bar_width * 3, sh, bar_width,
   #             alpha=opacity, 
                 color='r',
   #             error_kw=error_config,
                label='SH')
rects3 = ax.bar(index + bar_width * 3, sh_, bar_width,
   #             alpha=opacity, 
                 color='gray',
                 bottom=sh,
   #             error_kw=error_config,
                )

rects3 = ax.bar(index + bar_width * 4, la, bar_width,
    #            alpha=opacity, 
                 color='darkviolet',
    #            error_kw=error_config,
                label='LA')
rects3 = ax.bar(index + bar_width * 4, la_, bar_width,
    #            alpha=opacity, 
                 color='gray',
                 bottom=la,
    #            error_kw=error_config,
                label='With battery')
 
ax.set_xticks(index + bar_width*1.5)
ax.set_xticklabels(('RR', 'NE', 'CA', 'MP', 'MG', 'MC'))
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=6)
plt.xlabel("Scheduling algorithms")
plt.ylabel("Usage")
 
fig.tight_layout()
#plt.savefig('result.png', dpi=200)
plt.ylim(0.4, 1)
plt.savefig("../pic/4_13/svg/usage_with_battery.svg", format='svg')
#plt.show()

# %% [markdown]
# old

# %% [raw]
# cr_ = (0.16965996827580931, 0.14076147997591093, 0.0890587137201927, 0.06307283373716399, 0.06191362412090373, 0.10689837398373969)
# os_ = (0.1184965312190287, 0.012297324083250794, 0.029351833498513336, 0.02214172447968288, 0.021102081268582817, 0.02109910802775028)
# sh_ = (0.055448462929475695, 0.058142086330935316, 0.03573104693140805, 0.08653223658441045, 0.02548300536672632, 0.11519390810632135)
# mb_ = (0.17934490392648283, 0.07234956234032752, 0.08891245337753806, 0.08713718927926661, 0.07216385224274402, 0.08600527704485494)
# la_ = (0.038090349075975416, 0.06383164300202826, 0.029392276422764096, 0.16719301848049284, 0.016119341563786027, 0.13425557809330624)

# %% [raw]
# cr = (0.8271697530864198, 0.8276798780487804, 0.9018006134969326, 0.9361265432098765, 0.9361656441717792, 0.869768292682927)
# os = (0.8794202180376611, 0.5716570862239841, 0.9706481665014867, 0.9778582755203171, 0.9788979187314172, 0.9789008919722497)
# sh = (0.9445515370705243, 0.9266618705035972, 0.964268953068592, 0.8982648648648648, 0.9745169946332737, 0.8214462365591397)
# mb = (0.8126868421052632, 0.926515873015873, 0.8937322834645671, 0.9079947368421053, 0.9271, 0.8826754617414247)
# la = (0.9619096509240246, 0.9361683569979717, 0.9706077235772359, 0.6862772073921971, 0.983880658436214, 0.7932677484787019)
